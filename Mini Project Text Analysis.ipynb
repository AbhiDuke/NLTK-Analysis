# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import nltk

d = pd.read_csv('blockchain_data.csv',encoding='latin1')

# %%
#d.head()

# %%
x=pd.DataFrame(d['TI'],d['AB'],d['DE'])

# %%
#x.head()

# %%
#x

# %%
d['AB'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 911    False
# 912    False
# 913    False
# 914    False
# 915    False
# 916    False
# 917    False
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# 923    False
# 924    False
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932    False
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938    False
# 939    False
# 940    False
# Name: AB, Length: 941, dtype: bool

# %%
#asr=d['AB'].reshape

# %%
d['AB'].dropna(axis=0,inplace = True)

# %%
d['AB'].shape
# Out:
# (940,)

# %%
new_ab = pd.DataFrame(d['AB'])

# %%
new_ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 940 entries, 0 to 940
# Data columns (total 1 columns):
# AB    940 non-null object
# dtypes: object(1)
# memory usage: 14.7+ KB

# %%
#x.shape

# %%
#x.info

# %%
x.isnull()
# Out:
# DE                                                  Blockchain; Distributed databases; Blockchain application  \
# AB
# A blockchain is a decentralised linked data str...                                               True
# Nowadays Blockchain technology has a great mark...                                               True
# The recent emergence and use growth of cryptocu...                                               True
# The primary innovations behind Software Defined...                                               True
# Online digital content service becomes more and...                                               True
# New emerging manufacturing paradigms such as cl...                                               True
# NaN                                                                                              True
# Cloud storage platforms promise a convenient wa...                                               True
# ...

# %%
s=pd.DataFrame(d)

# %%
#s.head()

# %%
a=pd.DataFrame(data=[d['AB'],d['TI'],d['DE']])
b=a.transpose()

# %%
#b.head()

# %%
b.shape
# Out:
# (941, 3)

# %%
b.dropna(axis=0,inplace=True)

# %%
b.shape
# Out:
# (718, 3)

# %%
#b.head()

# %%
b.shape
# Out:
# (718, 3)

# %%
d=a.transpose()

# %%
d.shape
# Out:
# (941, 3)

# %%
d['AB'].dropna(axis=0,inplace=True)

# %%
d['TI'].shape
# Out:
# (941,)

# %%
d['DE'].shape
# Out:
# (941,)

# %%
d['DE'].fillna(" ")
# Out:
# 0      Blockchain; Distributed databases; Blockchain ...
# 1      Software development; Process; Blockchain; Sta...
# 2
# 3      SDN; Controller; DDoS attack; Information dist...
# 4      Digital rights management; Blockchain; Content...
# 5      Blockchain; Cloud manufacturing; Peer to peer ...
# 6
# 7      Cloud security; shared ownership; distributed ...
# 8      Financial markets; Cryptocurrencies; Bitcoin; ...
# 9      Internet of Things; Blockchain; Smart contract...
# 10     Bitcoin blockchain; Transaction network; Bitco...
# 11     Self-organized cyber physical power system; bl...
# 12
# 13     Bitcoin; Block; Blockchain; Chain; Cryptocurre...
# 14            Blockchain; mining pool; evolutionary game
# 15     Big data; Sovereign blockchain; Access control...
# 16     Federated cloud; Blockchain; Breach detection ...
# 17     networks; bankruptcy problems; systemic risk; ...
# 18     Cloud storage; Security; Blockchain; Architect...
# ...

# %%
new_b = pd.DataFrame(d['AB'],d['DE'].fillna(" "),d['TI'].fillna(" "))
#new_b.head()

# %%
a=a.transpose()
#a.head()

# %%
a.shape
# Out:
# (941, 3)

# %%
a['TI'].fillna(" ",axis=0,inplace=True)

# %%
a['DE'].fillna(" ",axis=0,inplace=True)

# %%
#a.head()

# %%
d.dropna(axis=0, inplace=True)

# %%
d.shape
# Out:
# (940, 3)

# %%
#d.head()

# %%
pct={}
for i in d.itertuples(index=True, name='Pandas'):
    news_x=(getattr(i,'AB'))

# %%
for key,value in d.iteritems():
    print(key,value)
# Out:
# AB 0      A blockchain is a decentralised linked data st...
# 1      Nowadays Blockchain technology has a great mar...
# 2      The recent emergence and use growth of cryptoc...
# 3      The primary innovations behind Software Define...
# 4      Online digital content service becomes more an...
# 5      New emerging manufacturing paradigms such as c...
# 7      Cloud storage platforms promise a convenient w...
# 8      Detection of power-law behavior and studies of...
# 9      In the Internet of Things (IoT) vision, conven...
# 10     As the first decentralized digital currency in...
# 11     The state parameters of electrical equipment a...
# 12     systems that not only communicate with other v...
# 13     The functioning of cryptocurrencies like Bitco...
# 14     In proof-of-work-based blockchain networks, th...
# 15     Technological advancements have brought about ...
# 16     Minimizing the breach detection gap (BDG) for ...
# ...

# %%
new_df=pd.DataFrame(d['AB'].str.strip())

# %%
#new_df.head()

# %%
d['AB'] = d['AB'].str.strip().str.lower()

# %%
#d['AB'].head()

# %%
import string
#p=string.punctuation
#pid = string.digits
#d['AB'].str.isnumeric()
#d['AB']=d['AB'].str.maketrans()

# %%
#from nltk.corpus import stopwords
#from nltk.tokenize import word_tokenize
#for key,value in d.iteritems():
#    a = word_tokenize(value)

# %%
d['AB']=d['AB'].str.replace('[{}]'.format(string.punctuation), ' ')

# %%
d['AB']=d['AB'].str.replace('[{}]'.format(string.digits), ' ')

# %%
#d['AB']

# %%
#Import stopword with scikit-learn
from sklearn.feature_extraction import text
stop = text.ENGLISH_STOP_WORDS

# %%
for i in stop :
    d['AB'] = d['AB'].replace(to_replace=r'\b%s\b'%i, value="",regex=True)

# %%
d['AB']=d['AB'].str.strip()

# %%
d['AB']

# %%
from nltk.stem import WordNetLemmatizer
w_l = WordNetLemmatizer()

# %%
#def lemmatize(s):
 #    s = [w_l.lemmatize(i) for i in s]
#     return s

#d['newl']=d['AB'].apply(lemmatize)

# %%
#import nltk
#nltk.download()

#w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
#lemmatizer = nltk.stem.WordNetLemmatizer()

#def lemmatize_text(text):
#    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

#df = pd.DataFrame(['this was cheesy', 'she likes these books', 'wow this is great'], columns=['text'])
#d['text_lemmatized'] = d['AB'].apply(lemmatize_text)

# %%
#d['new1']

# %%
#d

# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
  
# word cloud for cleaned Abstract
  
comment_words = ' '
stopwords = set(STOPWORDS) 
  

for val in d.AB: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
#word cloud for Topics 
  
comment_words = ' '
stopwords = set(STOPWORDS) 
  
for val in d.TI: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# word cloud for Keywords
  
comment_words = ' '
stopwords = set(STOPWORDS) 
for val in d.DE: 
       
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# NMF
import numpy as np  # a conventional alias
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import glob
import os
from sklearn import decomposition #for NMF

def parse_text(txt): #I made it very simple – you should use this for preprocessing
    txt = txt.lower()
    return txt
 
corpus = []

for f in d['AB']:
    #f_input = open(f)
    txt = f
    #txt = [w.strip() for w in txt.split()]
    corpus.append(txt)

# %%
#corpus

# %%
vectorizer = TfidfVectorizer(stop_words = 'english', min_df = 2)
dtm = vectorizer.fit_transform(corpus)
vocab = vectorizer.get_feature_names() #gets features/words
names = [fn[:-4] for fn in str(d['AB'])] #get file names without .txt

# %%
num_topics = 25
num_top_words = 20
clf = decomposition.NMF(n_components = num_topics, random_state=1)
doctopic = clf.fit_transform(dtm)
topic_words = []
for topic in clf.components_:
    word_idx = np.argsort(topic)[::-1][0:num_top_words]
    topic_words.append([vocab[i] for i in word_idx])

# %%
#topic_words

# %%
for t in range(len(topic_words)):
    print("\n Topic {}: {}".format(t, ' '.join(topic_words[t][:20])))
# Out:
#  Topic 0: blockchain technology research applications application potential challenges future paper study literature areas current solutions industry security decentralized use technical internet
#
#  Topic 1: data sharing big integrity privacy stored medical personal owners exchange solution shared platform trusted database using consent provenance processing paper
#
#  Topic 2: energy grid prosumers renewable distributed distribution transactive market internet demand smart microgrids generation exchanges trading based consumption blockchain consumers transactions
#
#  Topic 3: bitcoin transactions transaction network addresses blockchain payment bitcoins anonymity currency users address peer information time decentralized size public graph cryptocurrency
#
#  Topic 4: iot devices things internet security smart connected privacy issues fog management solutions manage applications device sensors architecture mainly lot paper
#
# ...

# %%
from sklearn.decomposition import LatentDirichletAllocation
#read in corpus, preprocess, etc. – NOT SHOWN
vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=10000, stop_words='english')
num_topics = 25 #arbitrary
dtm = vectorizer.fit_transform(corpus)

lda = LatentDirichletAllocation(n_components=num_topics, learning_method='batch', max_iter=2000, random_state=0)
 
document_topics = lda.fit_transform(dtm)
feature_names = vectorizer.get_feature_names()

                                
def display_topics(model, feature_names, n_top_words):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print(" ".join([feature_names[i]
        
        for i in topic.argsort()[:-n_top_words - 1:-1]]))
display_topics(lda, feature_names, 20)
# Out:
# Topic 0:
# search blockchain nodes malware distributed protocol payment payments root network feature based bitcoin data exploit throughput privacy result practical connectivity
# Topic 1:
# blockchain bitcoin systems transactions distributed based digital network peer public transaction new paper physical technology proof reliability value decentralized work
# Topic 2:
# signature scheme blockchain security based proposed firmware paper network key new blockchains embedded attacks user attack secure schemes nodes authentication
# Topic 3:
# blockchain iot security internet based data technology devices paper things smart cloud systems management information network computing service distributed architecture
# Topic 4:
# energy grid blockchain currency technologies based renewable urban digital smart home electric paper consumers technology storage issues solar cities potential
# Topic 5:
# ...

# %%
# Lemmatization results
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')

def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
# Out:
# C:\Users\AB Duke\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to C:\Users\AB
# [nltk_data]     Duke\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
words = []
for word in str(d.AB).split(' '):
    if len(word)>2:
        words.append(word)

# %%
# Not required 
#word_new = []
#for word in str(words).split(" "):
#    if len(word)>2:
#        word_new.append(word)
        
#word_new

# %%
# Appling NMF to the Preprocessed & Lmmetized data
vectorizer = TfidfVectorizer(stop_words = 'english', min_df = 2)
dtm = vectorizer.fit_transform(corpus)
vocab = vectorizer.get_feature_names() #gets features/words
names = [fn[:-4] for fn in str(words)] #get file names without .txt


num_topics = 25
num_top_words = 20
clf = decomposition.NMF(n_components = num_topics, random_state=1)
doctopic = clf.fit_transform(dtm)
topic_words = []
for topic in clf.components_:
    word_idx = np.argsort(topic)[::-1][0:num_top_words]
    topic_words.append([vocab[i] for i in word_idx])
for t in range(len(topic_words)):
    print("\n Topic {}: {}".format(t, ' '.join(topic_words[t][:20])))
# Out:
#  Topic 0: blockchain technology research applications application potential challenges future paper study literature areas current solutions industry security decentralized use technical internet
#
#  Topic 1: data sharing big integrity privacy stored medical personal owners exchange solution shared platform trusted database using consent provenance processing paper
#
#  Topic 2: energy grid prosumers renewable distributed distribution transactive market internet demand smart microgrids generation exchanges trading based consumption blockchain consumers transactions
#
#  Topic 3: bitcoin transactions transaction network addresses blockchain payment bitcoins anonymity currency users address peer information time decentralized size public graph cryptocurrency
#
#  Topic 4: iot devices things internet security smart connected privacy issues fog management solutions manage applications device sensors architecture mainly lot paper
#
# ...

# %%
from sklearn.cluster import KMeans
import pandas as pd
import nltk
#nltk.download()
freq = nltk.FreqDist(words)
#plot top 50

plt.figure(figsize=(26,5))
#plt.show()
freq.plot(100)

# %%
#new_ooo = []
#for i in corpus:
#    if len(i)>1:
#        new_ooo.append(i)

# %%
#new_po

# %%
#new_ooo

# %%
#new_oop = []
#for i in new_ooo:
#    i.split(' ')
#    if len(i)>1:
#        new_oop.append(i)

# %%
#new_oop
